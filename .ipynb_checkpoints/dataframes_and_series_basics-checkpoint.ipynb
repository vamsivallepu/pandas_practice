# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 85)

# %%
# I used the latest csv rather than using what used in video
df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_public.csv')
schema_df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_schema.csv')

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
# Accessing single column
df['Employment']

# return type : Series
# Series : Single columns and multiple rows
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
# Accessing multiple columns
df[['Employment', 'EdLevel']]

# return type : DataFrame
# Out:
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4      Employed, full-time;Independent contractor, fr...
# ...                                                  ...
# 89179  Employed, full-time;Independent contractor, fr...
# 89180             Student, full-time;Employed, part-time
# 89181                                I prefer not to say
# 89182             Employed, part-time;Student, part-time
# 89183                                Employed, full-time
#
#                                                  EdLevel
# 0                                                    NaN
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
# To retrieve columns of dataframe
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
# To retrieve rows using integers(index)
df.iloc[0]
# Out:
# ResponseId                           1
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 0, Length: 84, dtype: object

# %%
# To retrieve multple rows at once
df.iloc[[0, 3, 5]]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 5           6  I agree  I am a developer by profession  35-44 years old
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 3  Employed, full-time  Hybrid (some remote, some in-person)
# 5  Employed, full-time                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 3                                              Hobby
# 5  Hobby;Professional development or self-paced l...
#
#                                              EdLevel  \
# 0                                                NaN
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
# Combination of rows and columns (indexes)
df.iloc[[0, 3, 5], 4]
# Out:
# 0                    NaN
# 3    Employed, full-time
# 5    Employed, full-time
# Name: Employment, dtype: object

# %%
df.iloc[[0, 3, 5], [4, 7]]
# Out:
#             Employment                                            EdLevel
# 0                  NaN                                                NaN
# 3  Employed, full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5  Employed, full-time  Some college/university study without earning ...

# %%
# To retrieve rows using primary key
df.loc[0]
# Out:
# ResponseId                           1
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 0, Length: 84, dtype: object

# %%
df.loc[[0, 5]]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 5           6  I agree  I am a developer by profession  35-44 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 5  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 5  Hobby;Professional development or self-paced l...
#
#                                              EdLevel  \
# 0                                                NaN
# 5  Some college/university study without earning ...
#
#                                            LearnCode  \
# 0                                                NaN
# 5  Books / Physical media;Colleague;Online Course...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# ...

# %%
# Using columns names with loc
df.loc[[0, 3, 5], 'Employment']
# Out:
# 0                    NaN
# 3    Employed, full-time
# 5    Employed, full-time
# Name: Employment, dtype: object

# %%
df.loc[[0, 3, 5], ['Employment', 'EdLevel']]
# Out:
#             Employment                                            EdLevel
# 0                  NaN                                                NaN
# 3  Employed, full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5  Employed, full-time  Some college/university study without earning ...

# %%
# To get number of rows and columns
df.shape
# Out:
# (89184, 84)

# %%
df['TBranch']
# Out:
# 0        NaN
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 89179     No
# 89180    NaN
# 89181    NaN
# 89182    NaN
# 89183    Yes
# Name: TBranch, Length: 89184, dtype: object

# %%
# Count the frequency of each answer in above result
df['TBranch'].value_counts()
# Out:
# TBranch
# Yes    43872
# No     21896
# Name: count, dtype: int64

# %%
# Count of NaN values
df['TBranch'].isna().sum()
# Out:
# 23416

# %%
# To get a particular range of rows and columns
df.loc[:5, 'Employment':'LearnCode']  # Unline string and list slicing the right part here is included []
# Out:
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
# 5                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# ...

# %%
# Same using iloc
df.iloc[:5, 4:8] # here slicing is similar to list and string slicing i.e, right part is excluded [)
# Out:
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel
# ...
