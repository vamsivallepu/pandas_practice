# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_schema.csv', index_col='qname')

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
schema_df.head()
# Out:
#              qid                                           question  \
# qname
# S0         QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo   QID12                                  Browser Meta Info
# Q310      QID310  <div><span style="font-size:19px;"><strong>You...
# Q120      QID312
# S1          QID1  <span style="font-size:22px; font-family: aria...
#
#          force_resp  type selector
# qname
# S0            False    DB       TB
# MetaInfo      False  Meta  Browser
# Q310          False    DB       TB
# Q120           True    MC     SAVR
# S1            False    DB       TB

# %%
filt = (df['Country']=='India')
Indian_df=df[filt]

# %%
# Save to csv
Indian_df.to_csv('Datasets/stack-overflow-developer-survey-2023/Indian_Data.csv')

# %%
# sep='\t' for tab seperate data

# %%
# To deal with excel we need xlwt, openpyxl and xlrd modules

# %%
Indian_df.to_excel('Datasets/stack-overflow-developer-survey-2023/India_Data.xlsx')

# %%
# save as json
Indian_df.to_json('Datasets/stack-overflow-developer-survey-2023/India_Data.json', orient='records', lines=True)

# %%
json_df = pd.read_json('Datasets/stack-overflow-developer-survey-2023/India_Data.json', orient='records', lines=True)

# %%
json_df.head()
# Out:
#       Q120                      MainBranch              Age  \
# 0  I agree  I am a developer by profession  25-34 years old
# 1  I agree  I am a developer by profession  25-34 years old
# 2  I agree  I am a developer by profession  18-24 years old
# 3  I agree  I am a developer by profession  25-34 years old
# 4  I agree  I am a developer by profession  25-34 years old
#
#                            Employment                            RemoteWork  \
# 0  Not employed, but looking for work                                  None
# 1                 Employed, full-time  Hybrid (some remote, some in-person)
# 2                 Employed, full-time                                Remote
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                             In-person
#
#                            CodingActivities  \
# 0                                      None
# 1  Hobby;Contribute to open-source projects
# ...

# %%
# To connect with db install and use sqlalchemy module
# from sqlalchemy import create_engine
# import psycopg2
# engine = create_engine('database address')
# india_df.to_sql('sample_table', engine, if_exists='replace')
# sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
# sql_df.head()

# %%
# sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')
# sql_df.head()
