# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_public.csv')
schema_df = pd.read_csv('./Datasets/stack-overflow-developer-survey-2023/survey_results_schema.csv')

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
# Sort df by a column
df.sort_values(by='YearsCode') # use ascending=False to sort in descending order
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 14361       14362  I agree                              I am learning to code
# 31673       31674  I agree                        I code primarily as a hobby
# 6745         6746  I agree                              I am learning to code
# 9501         9502  I agree  I am not primarily a developer, but I write co...
# 12778       12779  I agree                              I am learning to code
# ...           ...      ...                                                ...
# 88883       88884  I agree                     I am a developer by profession
# 88940       88941  I agree                              I am learning to code
# 89028       89029  I agree                                      None of these
# 89134       89135  I agree                        I code primarily as a hobby
# 89159       89160  I agree                                      None of these
#
# ...

# %%
# Sorting based on multiple columns
# df.sort_values(by=[list of cols])

# %%
# Sorting based on multiple cols in different orders
# df.sort_values(by=['col1', 'col2'], ascendind=[False, True])

# %%
# Sort the df on index
df.sort_index()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
# sort our df on Country and salary
df.sort_values(by=['Country', 'ConvertedCompYearly'], ascending=[True, False],inplace=True)

# %%
df[['Country', 'ConvertedCompYearly']].head(50)
# Out:
#            Country  ConvertedCompYearly
# 88347  Afghanistan            9203683.0
# 86038  Afghanistan              68000.0
# 1334   Afghanistan               2403.0
# 57361  Afghanistan               2288.0
# 17872  Afghanistan               1144.0
# 36048  Afghanistan                915.0
# 53321  Afghanistan                794.0
# 41678  Afghanistan                648.0
# 39426  Afghanistan                 48.0
# 37955  Afghanistan                 41.0
# 2641   Afghanistan                 33.0
# 2300   Afghanistan                  NaN
# 3910   Afghanistan                  NaN
# 4221   Afghanistan                  NaN
# 4409   Afghanistan                  NaN
# 10142  Afghanistan                  NaN
# 10376  Afghanistan                  NaN
# 14419  Afghanistan                  NaN
# 15958  Afghanistan                  NaN
# 20377  Afghanistan                  NaN
# 21497  Afghanistan                  NaN
# 21672  Afghanistan                  NaN
# ...

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# 53268    74351432.0
# 77848    73607918.0
# 66223    72714292.0
# 28121    57513831.0
# 19679    36573181.0
# 55102    17612921.0
# 80586    11000000.0
# 83679    10319366.0
# 47797     9915585.0
# 88347     9203683.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10, 'ConvertedCompYearly')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 53268       53269  I agree                     I am a developer by profession
# 77848       77849  I agree                     I am a developer by profession
# 66223       66224  I agree                     I am a developer by profession
# 28121       28122  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 55102       55103  I agree  I am not primarily a developer, but I write co...
# 80586       80587  I agree                     I am a developer by profession
# 83679       83680  I agree                     I am a developer by profession
# 47797       47798  I agree                     I am a developer by profession
# 88347       88348  I agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...
